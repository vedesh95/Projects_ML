# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("cleanedNewCustomerList.csv")

# %%
df
# Out:
#      Unnamed: 0 first_name  last_name  gender  \
# 0             1    Chickie    Brister    Male
# 1             2      Morly     Genery    Male
# 2             3    Ardelis  Forrester  Female
# 3             4     Lucine      Stutt  Female
# 4             5    Melinda     Hadlee  Female
# ..          ...        ...        ...     ...
# 995         996  Ferdinand  Romanetti    Male
# 996         997       Burk    Wortley    Male
# 997         998   Melloney      Temby  Female
# 998         999     Dickie    Cubbini    Male
# 999        1000      Sylas    Duffill    Male
#
#      past_3_years_bike_related_purchases                  DOB  \
# 0                                     86           1957-07-12
# 1                                     69           1970-03-22
# 2                                     10  1974-08-28 00:00:00
# 3                                     64           1979-01-28
# 4                                     34           1965-09-21
# ...

# %%
plt.hist(df["gender"])
plt.ylabel("No of customer who broght the bikes")
plt.title("No of new Customers vs gender")
# Out:
# Text(0.5, 1.0, 'No of new Customers vs gender')

# %%
tempdf=pd.DataFrame(df["gender"])
tempdf["past_3_years_bike_related_purchases"]=df["past_3_years_bike_related_purchases"]
tempdf
li=tempdf.groupby(["gender"]).sum()
li["gender"]=["Female" ,"Male", "U"]
plt.bar(li["gender"], li["past_3_years_bike_related_purchases"], align='center', alpha=0.5)
plt.ylabel("past_3_years_bike_related_purchases")
plt.title("New Customers past_3_years_bike_related_purchases v/s gender")
# Out:
# Text(0.5, 1.0, 'New Customers past_3_years_bike_related_purchases v/s gender')

# %%
li=df["job_industry_category"].value_counts()
# plt.figure(figsize=(20,10))
plt.figure(figsize=(20,6))
plt.hist(df["job_industry_category"])
plt.ylabel("No. of customers")
plt.title("New Customers job_industry_category V/S No. of customers")
# Out:
# Text(0.5, 1.0, 'New Customers job_industry_category V/S No. of customers')

# %%
plt.hist(df["wealth_segment"])
plt.ylabel("No.of customers")
plt.title("No.of New Customers V/S wealth_segment")
# Out:
# Text(0.5, 1.0, 'No.of New Customers V/S wealth_segment')

# %%
plt.hist(df["state"])
plt.ylabel("No.of customers")
plt.xlabel("State")
plt.title("No.of New Customers V/S state")
# Out:
# Text(0.5, 1.0, 'No.of New Customers V/S state')

# %%
temp = pd.DatetimeIndex(df['DOB']).year
df["year"]=temp
df["age"]=2020-df["year"]
agelist=df["age"].to_list()
templi=[]
for i in agelist:
   
    if i>=0 and i<20:
        templi.append("0-20")
    elif i>=20 and i<30:
        templi.append("20-30")
    elif i>=30 and i<40:
        templi.append("30-40")
    elif i>=40 and i<50:
        templi.append("40-50")
    elif i>=50 and i<60:
        templi.append("50-60")
    elif i>=60:
        templi.append("above 60")
df["age category"]=templi

# %%
plt.hist(df["age category"])
plt.ylabel("No.of customers")
plt.xlabel("age category")
plt.title("No.of New Customers V/S age_category")
# Out:
# Text(0.5, 1.0, 'No.of New Customers V/S age_category')

# %%
df
# Out:
#      Unnamed: 0 first_name  last_name  gender  \
# 0             1    Chickie    Brister    Male
# 1             2      Morly     Genery    Male
# 2             3    Ardelis  Forrester  Female
# 3             4     Lucine      Stutt  Female
# 4             5    Melinda     Hadlee  Female
# ..          ...        ...        ...     ...
# 995         996  Ferdinand  Romanetti    Male
# 996         997       Burk    Wortley    Male
# 997         998   Melloney      Temby  Female
# 998         999     Dickie    Cubbini    Male
# 999        1000      Sylas    Duffill    Male
#
#      past_3_years_bike_related_purchases                  DOB  \
# 0                                     86           1957-07-12
# 1                                     69           1970-03-22
# 2                                     10  1974-08-28 00:00:00
# 3                                     64           1979-01-28
# 4                                     34           1965-09-21
# ...
