# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("cleanedNewCustomerList.csv")

# %%
df
# Out:
#      Unnamed: 0 first_name  last_name  gender  \
# 0             1    Chickie    Brister    Male
# 1             2      Morly     Genery    Male
# 2             3    Ardelis  Forrester  Female
# 3             4     Lucine      Stutt  Female
# 4             5    Melinda     Hadlee  Female
# ..          ...        ...        ...     ...
# 995         996  Ferdinand  Romanetti    Male
# 996         997       Burk    Wortley    Male
# 997         998   Melloney      Temby  Female
# 998         999     Dickie    Cubbini    Male
# 999        1000      Sylas    Duffill    Male
#
#      past_3_years_bike_related_purchases                  DOB  \
# 0                                     86           1957-07-12
# 1                                     69           1970-03-22
# 2                                     10  1974-08-28 00:00:00
# 3                                     64           1979-01-28
# 4                                     34           1965-09-21
# ..                                   ...                  ...
# 995                                   60           1959-10-07
# 996                                   22           2001-10-17
# 997                                   17           1954-10-05
# 998                                   30           1952-12-17
# 999                                   56           1955-10-02
#
#                         job_title job_industry_category     wealth_segment  \
# 0                 General Manager         Manufacturing      Mass Customer
# 1             Structural Engineer              Property      Mass Customer
# 2          Senior Cost Accountant    Financial Services  Affluent Customer
# 3      Account Representative III         Manufacturing  Affluent Customer
# 4               Financial Analyst    Financial Services  Affluent Customer
# ..                            ...                   ...                ...
# 995                     Paralegal    Financial Services  Affluent Customer
# 996        Senior Sales Associate                Health      Mass Customer
# 997  Budget/Accounting Analyst IV    Financial Services  Affluent Customer
# 998             Financial Advisor    Financial Services      Mass Customer
# 999           Staff Accountant IV              Property      Mass Customer
#
#     deceased_indicator owns_car  tenure                   address  postcode  \
# 0                    N      Yes      14          45 Shopko Center      4500
# 1                    N       No      16         14 Mccormick Park      2113
# 2                    N       No      10       5 Colorado Crossing      3505
# 3                    N      Yes       5        207 Annamark Plaza      4814
# 4                    N       No      19         115 Montana Place      2093
# ..                 ...      ...     ...                       ...       ...
# 995                  N       No       9               2 Sloan Way      2200
# 996                  N       No       6         04 Union Crossing      2196
# 997                  N      Yes      15  33475 Fair Oaks Junction      4702
# 998                  N      Yes      19        57666 Victoria Way      4215
# 999                  N      Yes      14        21875 Grover Drive      2010
#
#     state    country  property_valuation  Rank     Value
# 0     QLD  Australia                   6     1  1.718750
# 1     NSW  Australia                  11     1  1.718750
# 2     VIC  Australia                   5     1  1.718750
# 3     QLD  Australia                   1     4  1.703125
# 4     NSW  Australia                   9     4  1.703125
# ..    ...        ...                 ...   ...       ...
# 995   NSW  Australia                   7   996  0.374000
# 996   NSW  Australia                  10   997  0.357000
# 997   QLD  Australia                   2   997  0.357000
# 998   QLD  Australia                   2   997  0.357000
# 999   NSW  Australia                   9  1000  0.340000
#
# [1000 rows x 19 columns]

# %%
plt.hist(df["gender"])
plt.ylabel("No of customer who broght the bikes")
plt.title("No of customers vs gender")
# Out:
# Text(0.5, 1.0, 'No of customers vs gender')

# %%
tempdf=pd.DataFrame(df["gender"])
tempdf["past_3_years_bike_related_purchases"]=df["past_3_years_bike_related_purchases"]
tempdf
li=tempdf.groupby(["gender"]).sum()
li["gender"]=["Female" ,"Male", "U"]
plt.bar(li["gender"], li["past_3_years_bike_related_purchases"], align='center', alpha=0.5)
plt.ylabel("past_3_years_bike_related_purchases")
plt.title("past_3_years_bike_related_purchases v/s gender")
# Out:
# Text(0.5, 1.0, 'past_3_years_bike_related_purchases v/s gender')

# %%
li=df["job_industry_category"].value_counts()
# plt.figure(figsize=(20,10))
plt.figure(figsize=(20,10))
plt.hist(df["job_industry_category"])
# Out:
# (array([246.,  80., 230.,  49.,   0.,  86.,  63.,  31., 185.,  30.]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. , 4.8, 5.6, 6.4, 7.2, 8. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df["wealth_segment"])
plt.ylabel("No.of customers")
plt.title("No.of customers V/S wealth_segment")
# Out:
# Text(0.5, 1.0, 'No.of customers V/S wealth_segment')

# %%
plt.hist(df["state"])
plt.ylabel("No.of customers")
plt.xlabel("State")
plt.title("No.of customers V/S state")
# Out:
# Text(0.5, 1.0, 'No.of customers V/S state')

# %%
temp = pd.DatetimeIndex(df['DOB']).year
df["year"]=temp
df["age"]=2020-df["year"]
agelist=df["age"].to_list()
templi=[]
for i in agelist:
   
    if i>=0 and i<20:
        templi.append("0-20")
    elif i>=20 and i<30:
        templi.append("20-30")
    elif i>=30 and i<40:
        templi.append("30-40")
    elif i>=40 and i<50:
        templi.append("40-50")
    elif i>=50 and i<60:
        templi.append("50-60")
    elif i>=60:
        templi.append("above 60")
df["age category"]=templi

# %%
plt.hist(df["age category"])
plt.ylabel("No.of customers")
plt.xlabel("age category")
plt.title("No.of customers V/S age_category")
# Out:
# Text(0.5, 1.0, 'No.of customers V/S age_category')

# %%
# Out:
# ['above 60',
#  '50-60',
#  '40-50',
#  '40-50',
#  '50-60',
#  'above 60',
#  '40-50',
#  '40-50',
#  '40-50',
#  '30-40',
#  '20-30',
#  '20-30',
#  '30-40',
#  '40-50',
#  '50-60',
#  'above 60',
#  '20-30',
#  '40-50',
#  'above 60',
#  'above 60',
#  '50-60',
#  '20-30',
#  '20-30',
#  '40-50',
#  '30-40',
#  'above 60',
#  'above 60',
#  '50-60',
#  'above 60',
#  'above 60',
#  '40-50',
#  'above 60',
#  '30-40',
#  '30-40',
#  '40-50',
#  '40-50',
#  '50-60',
#  '40-50',
#  'above 60',
#  '20-30',
#  'above 60',
#  '30-40',
#  'above 60',
#  '50-60',
#  '50-60',
#  'above 60',
#  'above 60',
#  '20-30',
#  '40-50',
#  'above 60',
#  '40-50',
#  '20-30',
#  '20-30',
#  '30-40',
#  '20-30',
#  '30-40',
#  '40-50',
#  '40-50',
#  '50-60',
#  '50-60',
#  '30-40',
#  '40-50',
#  'above 60',
#  '50-60',
#  '20-30',
#  '30-40',
#  '20-30',
#  '30-40',
#  '20-30',
#  '30-40',
#  '20-30',
#  '20-30',
#  '20-30',
#  '50-60',
#  'above 60',
#  '40-50',
#  '50-60',
#  'above 60',
#  '40-50',
#  '40-50',
#  '20-30',
#  '50-60',
#  '30-40',
#  '40-50',
#  '50-60',
#  'above 60',
#  '20-30',
#  'above 60',
#  'above 60',
#  '40-50',
#  '20-30',
#  '40-50',
#  '40-50',
#  'above 60',
#  '40-50',
#  '20-30',
#  'above 60',
#  '20-30',
#  '40-50',
#  '20-30',
#  '20-30',
#  '20-30',
#  'above 60',
#  '40-50',
#  '50-60',
#  'above 60',
#  '50-60',
#  '40-50',
#  '50-60',
#  '50-60',
#  '50-60',
#  'above 60',
#  '50-60',
#  '20-30',
#  '40-50',
#  '20-30',
#  'above 60',
#  '40-50',
#  '30-40',
#  'above 60',
#  '30-40',
#  '20-30',
#  '50-60',
#  '40-50',
#  'above 60',
#  'above 60',
#  'above 60',
#  '40-50',
#  'above 60',
#  '30-40',
#  '50-60',
#  '50-60',
#  'above 60',
#  '30-40',
#  '40-50',
#  '50-60',
#  '30-40',
#  '50-60',
#  '40-50',
#  '40-50',
#  '50-60',
#  '10-20',
#  'above 60',
#  '40-50',
#  '30-40',
#  'above 60',
#  '50-60',
#  '50-60',
#  '50-60',
#  '40-50',
#  '50-60',
#  '50-60',
#  '50-60',
#  '50-60',
#  'above 60',
#  '50-60',
#  '40-50',
#  'above 60',
#  '40-50',
#  'above 60',
#  '30-40',
#  '20-30',
#  '50-60',
#  'above 60',
#  '40-50',
#  '40-50',
#  '40-50',
#  '30-40',
#  'above 60',
#  '30-40',
#  'above 60',
#  'above 60',
#  '30-40',
#  '20-30',
#  'above 60',
#  '20-30',
#  'above 60',
#  'above 60',
#  'above 60',
#  '40-50',
#  '50-60',
#  '40-50',
#  'above 60',
#  '40-50',
#  '30-40',
#  '20-30',
#  '40-50',
#  '40-50',
#  '30-40',
#  '20-30',
#  '20-30',
#  'above 60',
#  '50-60',
#  '50-60',
#  'above 60',
#  '40-50',
#  '30-40',
#  '30-40',
#  '20-30',
#  '50-60',
#  'above 60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '20-30',
#  'above 60',
#  '40-50',
#  'above 60',
#  'above 60',
#  '50-60',
#  '50-60',
#  '30-40',
#  '20-30',
#  'above 60',
#  'above 60',
#  '20-30',
#  '20-30',
#  '50-60',
#  '40-50',
#  '20-30',
#  '30-40',
#  '40-50',
#  '50-60',
#  '20-30',
#  '40-50',
#  '20-30',
#  '20-30',
#  '50-60',
#  'above 60',
#  '50-60',
#  '40-50',
#  'above 60',
#  '50-60',
#  'above 60',
#  '20-30',
#  'above 60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '50-60',
#  '40-50',
#  'above 60',
#  '50-60',
#  'above 60',
#  'above 60',
#  '50-60',
#  '50-60',
#  '40-50',
#  '40-50',
#  '40-50',
#  '40-50',
#  '50-60',
#  '50-60',
#  '40-50',
#  '20-30',
#  'above 60',
#  'above 60',
#  '50-60',
#  '20-30',
#  '40-50',
#  '50-60',
#  '20-30',
#  '20-30',
#  'above 60',
#  '20-30',
#  'above 60',
#  '50-60',
#  '40-50',
#  'above 60',
#  '40-50',
#  '20-30',
#  '50-60',
#  '40-50',
#  'above 60',
#  '40-50',
#  '50-60',
#  'above 60',
#  '50-60',
#  '40-50',
#  '50-60',
#  '50-60',
#  '40-50',
#  '40-50',
#  'above 60',
#  '50-60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '40-50',
#  '30-40',
#  '30-40',
#  '40-50',
#  'above 60',
#  '50-60',
#  '40-50',
#  '30-40',
#  '50-60',
#  '50-60',
#  '20-30',
#  'above 60',
#  '30-40',
#  '20-30',
#  '30-40',
#  'above 60',
#  'above 60',
#  '40-50',
#  'above 60',
#  'above 60',
#  '30-40',
#  '40-50',
#  '20-30',
#  '50-60',
#  '30-40',
#  '50-60',
#  '20-30',
#  '40-50',
#  'above 60',
#  '30-40',
#  'above 60',
#  '30-40',
#  '40-50',
#  '40-50',
#  '30-40',
#  '20-30',
#  '20-30',
#  'above 60',
#  'above 60',
#  '30-40',
#  '40-50',
#  '40-50',
#  '20-30',
#  'above 60',
#  '20-30',
#  '40-50',
#  'above 60',
#  'above 60',
#  '20-30',
#  '40-50',
#  'above 60',
#  '40-50',
#  '50-60',
#  '50-60',
#  'above 60',
#  'above 60',
#  '50-60',
#  'above 60',
#  'above 60',
#  '50-60',
#  'above 60',
#  '30-40',
#  'above 60',
#  '50-60',
#  'above 60',
#  'above 60',
#  '10-20',
#  '40-50',
#  'above 60',
#  '40-50',
#  '40-50',
#  '30-40',
#  '30-40',
#  '40-50',
#  '20-30',
#  'above 60',
#  '20-30',
#  '30-40',
#  '40-50',
#  'above 60',
#  'above 60',
#  '20-30',
#  '40-50',
#  '50-60',
#  '40-50',
#  '40-50',
#  '40-50',
#  'above 60',
#  '40-50',
#  '30-40',
#  '40-50',
#  'above 60',
#  '50-60',
#  '20-30',
#  '50-60',
#  'above 60',
#  '20-30',
#  'above 60',
#  '50-60',
#  '40-50',
#  '20-30',
#  'above 60',
#  '40-50',
#  'above 60',
#  '30-40',
#  'above 60',
#  '30-40',
#  '50-60',
#  '10-20',
#  '50-60',
#  'above 60',
#  '40-50',
#  '40-50',
#  '50-60',
#  'above 60',
#  '40-50',
#  '40-50',
#  '40-50',
#  'above 60',
#  '20-30',
#  '30-40',
#  'above 60',
#  'above 60',
#  '20-30',
#  'above 60',
#  'above 60',
#  'above 60',
#  '50-60',
#  'above 60',
#  '30-40',
#  '20-30',
#  '20-30',
#  'above 60',
#  '50-60',
#  '20-30',
#  '20-30',
#  'above 60',
#  'above 60',
#  '40-50',
#  '50-60',
#  '40-50',
#  'above 60',
#  '40-50',
#  '40-50',
#  'above 60',
#  '40-50',
#  '40-50',
#  '40-50',
#  '20-30',
#  '40-50',
#  'above 60',
#  'above 60',
#  'above 60',
#  '20-30',
#  '30-40',
#  '50-60',
#  '40-50',
#  '20-30',
#  'above 60',
#  '50-60',
#  '40-50',
#  '20-30',
#  '20-30',
#  '20-30',
#  'above 60',
#  '30-40',
#  '30-40',
#  '50-60',
#  '40-50',
#  '40-50',
#  'above 60',
#  'above 60',
#  '40-50',
#  'above 60',
#  'above 60',
#  '50-60',
#  '40-50',
#  '20-30',
#  '40-50',
#  '50-60',
#  '20-30',
#  '10-20',
#  '30-40',
#  '50-60',
#  '20-30',
#  'above 60',
#  '40-50',
#  '10-20',
#  '40-50',
#  '20-30',
#  'above 60',
#  'above 60',
#  '40-50',
#  'above 60',
#  'above 60',
#  '50-60',
#  '50-60',
#  'above 60',
#  '50-60',
#  '50-60',
#  '20-30',
#  '40-50',
#  '40-50',
#  '50-60',
#  '20-30',
#  'above 60',
#  '40-50',
#  '20-30',
#  'above 60',
#  'above 60',
#  '30-40',
#  'above 60',
#  '50-60',
#  '40-50',
#  '40-50',
#  'above 60',
#  '40-50',
#  'above 60',
#  '40-50',
#  '40-50',
#  '40-50',
#  '40-50',
#  '40-50',
#  '20-30',
#  '40-50',
#  'above 60',
#  '30-40',
#  '40-50',
#  '10-20',
#  '50-60',
#  '20-30',
#  'above 60',
#  'above 60',
#  'above 60',
#  '20-30',
#  'above 60',
#  '40-50',
#  'above 60',
#  '50-60',
#  'above 60',
#  '40-50',
#  '40-50',
#  '20-30',
#  '30-40',
#  '30-40',
#  'above 60',
#  'above 60',
#  'above 60',
#  '40-50',
#  '20-30',
#  '40-50',
#  '20-30',
#  '50-60',
#  '40-50',
#  '40-50',
#  'above 60',
#  '20-30',
#  '40-50',
#  '40-50',
#  '40-50',
#  '30-40',
#  '20-30',
#  '40-50',
#  '40-50',
#  '20-30',
#  'above 60',
#  '20-30',
#  '20-30',
#  '40-50',
#  '20-30',
#  'above 60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '20-30',
#  '50-60',
#  'above 60',
#  'above 60',
#  '50-60',
#  '30-40',
#  '20-30',
#  '10-20',
#  '50-60',
#  'above 60',
#  'above 60',
#  '50-60',
#  '50-60',
#  '20-30',
#  'above 60',
#  '40-50',
#  '20-30',
#  '20-30',
#  '40-50',
#  '30-40',
#  '20-30',
#  '20-30',
#  'above 60',
#  'above 60',
#  '20-30',
#  '20-30',
#  '40-50',
#  '30-40',
#  '40-50',
#  '20-30',
#  '50-60',
#  'above 60',
#  '40-50',
#  'above 60',
#  '40-50',
#  '20-30',
#  '20-30',
#  'above 60',
#  '20-30',
#  '20-30',
#  '40-50',
#  '50-60',
#  '50-60',
#  'above 60',
#  'above 60',
#  '40-50',
#  '50-60',
#  '20-30',
#  '40-50',
#  '50-60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '50-60',
#  'above 60',
#  '40-50',
#  'above 60',
#  '50-60',
#  'above 60',
#  'above 60',
#  '20-30',
#  '50-60',
#  'above 60',
#  '20-30',
#  '40-50',
#  '50-60',
#  'above 60',
#  'above 60',
#  '30-40',
#  '50-60',
#  '40-50',
#  '20-30',
#  'above 60',
#  'above 60',
#  '40-50',
#  'above 60',
#  'above 60',
#  '50-60',
#  '50-60',
#  '30-40',
#  '20-30',
#  '50-60',
#  '40-50',
#  'above 60',
#  '20-30',
#  '30-40',
#  'above 60',
#  'above 60',
#  '30-40',
#  '40-50',
#  '20-30',
#  'above 60',
#  'above 60',
#  'above 60',
#  '30-40',
#  'above 60',
#  '40-50',
#  '50-60',
#  '20-30',
#  'above 60',
#  '40-50',
#  'above 60',
#  'above 60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '40-50',
#  '40-50',
#  'above 60',
#  'above 60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '50-60',
#  'above 60',
#  '50-60',
#  '20-30',
#  '50-60',
#  '20-30',
#  'above 60',
#  '30-40',
#  '40-50',
#  '40-50',
#  '40-50',
#  '20-30',
#  'above 60',
#  '20-30',
#  'above 60',
#  '20-30',
#  '40-50',
#  '40-50',
#  'above 60',
#  '40-50',
#  '20-30',
#  'above 60',
#  'above 60',
#  '50-60',
#  '40-50',
#  '30-40',
#  '40-50',
#  '50-60',
#  '40-50',
#  'above 60',
#  'above 60',
#  '40-50',
#  'above 60',
#  '20-30',
#  '40-50',
#  '30-40',
#  '30-40',
#  '40-50',
#  '40-50',
#  'above 60',
#  '50-60',
#  '50-60',
#  '50-60',
#  '20-30',
#  '50-60',
#  '40-50',
#  '40-50',
#  '50-60',
#  '40-50',
#  '50-60',
#  '50-60',
#  '20-30',
#  '20-30',
#  'above 60',
#  '50-60',
#  '20-30',
#  '20-30',
#  'above 60',
#  '20-30',
#  '30-40',
#  '30-40',
#  '50-60',
#  '50-60',
#  '40-50',
#  'above 60',
#  'above 60',
#  '40-50',
#  '10-20',
#  'above 60',
#  '20-30',
#  '40-50',
#  '40-50',
#  '50-60',
#  '40-50',
#  '40-50',
#  'above 60',
#  'above 60',
#  'above 60',
#  '50-60',
#  '40-50',
#  '50-60',
#  '20-30',
#  '40-50',
#  '30-40',
#  '40-50',
#  '40-50',
#  '30-40',
#  'above 60',
#  '10-20',
#  '30-40',
#  'above 60',
#  '20-30',
#  '30-40',
#  '50-60',
#  'above 60',
#  'above 60',
#  '30-40',
#  'above 60',
#  '30-40',
#  '20-30',
#  '20-30',
#  '30-40',
#  '50-60',
#  '40-50',
#  '20-30',
#  '30-40',
#  '50-60',
#  'above 60',
#  '20-30',
#  '20-30',
#  'above 60',
#  'above 60',
#  '30-40',
#  '40-50',
#  '20-30',
#  '40-50',
#  '40-50',
#  'above 60',
#  'above 60',
#  'above 60',
#  '50-60',
#  '50-60',
#  'above 60',
#  '30-40',
#  'above 60',
#  '30-40',
#  '40-50',
#  '40-50',
#  'above 60',
#  'above 60',
#  'above 60',
#  '50-60',
#  'above 60',
#  '30-40',
#  '50-60',
#  '50-60',
#  'above 60',
#  '40-50',
#  '20-30',
#  'above 60',
#  '20-30',
#  'above 60',
#  'above 60',
#  '50-60',
#  '30-40',
#  '30-40',
#  '40-50',
#  '50-60',
#  '40-50',
#  '40-50',
#  '40-50',
#  '20-30',
#  '20-30',
#  '50-60',
#  '20-30',
#  '50-60',
#  '40-50',
#  '50-60',
#  '50-60',
#  '50-60',
#  '50-60',
#  '40-50',
#  'above 60',
#  '20-30',
#  'above 60',
#  'above 60',
#  '40-50',
#  'above 60',
#  '10-20',
#  '40-50',
#  '20-30',
#  '20-30',
#  '30-40',
#  '20-30',
#  'above 60',
#  'above 60',
#  'above 60',
#  '20-30',
#  'above 60',
#  '40-50',
#  '40-50',
#  'above 60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '40-50',
#  '40-50',
#  'above 60',
#  '20-30',
#  '30-40',
#  'above 60',
#  '50-60',
#  '50-60',
#  'above 60',
#  '40-50',
#  '50-60',
#  '50-60',
#  'above 60',
#  '40-50',
#  '40-50',
#  '20-30',
#  'above 60',
#  'above 60',
#  '20-30',
#  '50-60',
#  'above 60',
#  '40-50',
#  '20-30',
#  '20-30',
#  '50-60',
#  'above 60',
#  '20-30',
#  'above 60',
#  '40-50',
#  '40-50',
#  'above 60',
#  '40-50',
#  '20-30',
#  '30-40',
#  '20-30',
#  '50-60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '50-60',
#  '50-60',
#  '50-60',
#  '20-30',
#  '40-50',
#  '40-50',
#  '40-50',
#  '50-60',
#  '50-60',
#  '20-30',
#  'above 60',
#  '40-50',
#  '20-30',
#  'above 60',
#  '50-60',
#  'above 60',
#  '30-40',
#  '40-50',
#  '30-40',
#  '30-40',
#  'above 60',
#  'above 60',
#  '30-40',
#  '30-40',
#  '30-40',
#  '40-50',
#  'above 60',
#  'above 60',
#  '20-30',
#  '40-50',
#  '20-30',
#  'above 60',
#  '40-50',
#  '30-40',
#  '40-50',
#  'above 60',
#  '50-60',
#  '50-60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '40-50',
#  'above 60',
#  '40-50',
#  '40-50',
#  '20-30',
#  'above 60',
#  '30-40',
#  '20-30',
#  '20-30',
#  '30-40',
#  '40-50',
#  '50-60',
#  '40-50',
#  '50-60',
#  '20-30',
#  '50-60',
#  '20-30',
#  '50-60',
#  '20-30',
#  '50-60',
#  '40-50',
#  '30-40',
#  '50-60',
#  '40-50',
#  '40-50',
#  '20-30',
#  '50-60',
#  'above 60',
#  '30-40',
#  'above 60',
#  '50-60',
#  '20-30',
#  '20-30',
#  '50-60',
#  '10-20',
#  '50-60',
#  '50-60',
#  'above 60',
#  '40-50',
#  '30-40',
#  '20-30',
#  'above 60',
#  'above 60',
#  'above 60',
#  'above 60',
#  '30-40',
#  'above 60',
#  '20-30',
#  'above 60',
#  'above 60',
#  'above 60',
#  '40-50',
#  '40-50',
#  'above 60',
#  '30-40',
#  'above 60',
#  '10-20',
#  'above 60',
#  'above 60',
#  'above 60']

# %%
# Out:
#      Unnamed: 0 first_name  last_name  gender  \
# 0             1    Chickie    Brister    Male
# 1             2      Morly     Genery    Male
# 2             3    Ardelis  Forrester  Female
# 3             4     Lucine      Stutt  Female
# 4             5    Melinda     Hadlee  Female
# ..          ...        ...        ...     ...
# 995         996  Ferdinand  Romanetti    Male
# 996         997       Burk    Wortley    Male
# 997         998   Melloney      Temby  Female
# 998         999     Dickie    Cubbini    Male
# 999        1000      Sylas    Duffill    Male
#
#      past_3_years_bike_related_purchases                  DOB  \
# 0                                     86           1957-07-12
# 1                                     69           1970-03-22
# 2                                     10  1974-08-28 00:00:00
# 3                                     64           1979-01-28
# 4                                     34           1965-09-21
# ..                                   ...                  ...
# 995                                   60           1959-10-07
# 996                                   22           2001-10-17
# 997                                   17           1954-10-05
# 998                                   30           1952-12-17
# 999                                   56           1955-10-02
#
#                         job_title job_industry_category     wealth_segment  \
# 0                 General Manager         Manufacturing      Mass Customer
# 1             Structural Engineer              Property      Mass Customer
# 2          Senior Cost Accountant    Financial Services  Affluent Customer
# 3      Account Representative III         Manufacturing  Affluent Customer
# 4               Financial Analyst    Financial Services  Affluent Customer
# ..                            ...                   ...                ...
# 995                     Paralegal    Financial Services  Affluent Customer
# 996        Senior Sales Associate                Health      Mass Customer
# 997  Budget/Accounting Analyst IV    Financial Services  Affluent Customer
# 998             Financial Advisor    Financial Services      Mass Customer
# 999           Staff Accountant IV              Property      Mass Customer
#
#     deceased_indicator  ...                   address  postcode state  \
# 0                    N  ...          45 Shopko Center      4500   QLD
# 1                    N  ...         14 Mccormick Park      2113   NSW
# 2                    N  ...       5 Colorado Crossing      3505   VIC
# 3                    N  ...        207 Annamark Plaza      4814   QLD
# 4                    N  ...         115 Montana Place      2093   NSW
# ..                 ...  ...                       ...       ...   ...
# 995                  N  ...               2 Sloan Way      2200   NSW
# 996                  N  ...         04 Union Crossing      2196   NSW
# 997                  N  ...  33475 Fair Oaks Junction      4702   QLD
# 998                  N  ...        57666 Victoria Way      4215   QLD
# 999                  N  ...        21875 Grover Drive      2010   NSW
#
#        country property_valuation  Rank     Value  year  age  age category
# 0    Australia                  6     1  1.718750  1957   63      above 60
# 1    Australia                 11     1  1.718750  1970   50         50-60
# 2    Australia                  5     1  1.718750  1974   46         40-50
# 3    Australia                  1     4  1.703125  1979   41         40-50
# 4    Australia                  9     4  1.703125  1965   55         50-60
# ..         ...                ...   ...       ...   ...  ...           ...
# 995  Australia                  7   996  0.374000  1959   61      above 60
# 996  Australia                 10   997  0.357000  2001   19         10-20
# 997  Australia                  2   997  0.357000  1954   66      above 60
# 998  Australia                  2   997  0.357000  1952   68      above 60
# 999  Australia                  9  1000  0.340000  1955   65      above 60
#
# [1000 rows x 22 columns]
