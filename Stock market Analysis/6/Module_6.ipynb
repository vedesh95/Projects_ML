# %% [markdown]
# # MODULE 6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.DataFrame()
temp=pd.read_csv('Large_Cap/Large_Cap/INFY.csv')
df['INFY']=temp["Close Price"]
temp=pd.read_csv('Large_Cap/Large_Cap/IOC.csv')
df['IOC']=temp["Close Price"]
temp=pd.read_csv('Large_Cap/Large_Cap/ITC.csv')
df['ITC']=temp["Close Price"]
temp=pd.read_csv('Large_Cap/Large_Cap/LT.csv')
df['LT']=temp["Close Price"]
temp=pd.read_csv('Large_Cap/Large_Cap/M&M.csv')
df['M&M']=temp["Close Price"]
temp=pd.read_csv('Large_Cap/Large_Cap/MARUTI.csv')
df['MARUTI']=temp["Close Price"]
temp=pd.read_csv('Large_Cap/Large_Cap/RELIANCE.csv')
df['RELIANCE']=temp["Close Price"]
temp=pd.read_csv('Large_Cap/Large_Cap/SUNPHARMA.csv')
df['SUNPHARMA']=temp["Close Price"]
temp=pd.read_csv('Large_Cap/Large_Cap/TCS.csv')
df['TCS']=temp["Close Price"]
temp=pd.read_csv('Large_Cap/Large_Cap/TITAN.csv')
df['TITAN']=temp["Close Price"]

temp=pd.read_csv('Mid_Cap/Mid_Cap/MRPL.csv')
df['MRPL']=temp["Close Price"]
temp=pd.read_csv('Mid_Cap/Mid_Cap/MUTHOOTFIN.csv')
df['MUTHOOTFIN']=temp["Close Price"]
temp=pd.read_csv('Mid_Cap/Mid_Cap/NBCC.csv')
df['NBCC']=temp["Close Price"]
temp=pd.read_csv('Mid_Cap/Mid_Cap/PNB.csv')
df['PNB']=temp["Close Price"]
temp=pd.read_csv('Mid_Cap/Mid_Cap/RBLBANK.csv')
df['RBLBANK']=temp["Close Price"]
temp=pd.read_csv('Mid_Cap/Mid_Cap/RELINFRA.csv')
df['RELINFRA']=temp["Close Price"]
temp=pd.read_csv('Mid_Cap/Mid_Cap/SUNTV.csv')
df['SUNTV']=temp["Close Price"]
temp=pd.read_csv('Mid_Cap/Mid_Cap/TATACHEM.csv')
df['TATACHEM']=temp["Close Price"]
temp=pd.read_csv('Mid_Cap/Mid_Cap/TATAPOWER.csv')
df['TATAPOWER']=temp["Close Price"]
temp=pd.read_csv('Mid_Cap/Mid_Cap/VOLTAS.csv')
df['VOLTAS']=temp["Close Price"]

temp=pd.read_csv('Small_Cap/Small_Cap/MINDAIND.csv')
df['MINDAIND']=temp["Close Price"]
temp=pd.read_csv('Small_Cap/Small_Cap/NCC.csv')
df['NCC']=temp["Close Price"]
temp=pd.read_csv('Small_Cap/Small_Cap/PVR.csv')
df['PVR']=temp["Close Price"]
temp=pd.read_csv('Small_Cap/Small_Cap/RAYMOND.csv')
df['RAYMOND']=temp["Close Price"]
temp=pd.read_csv('Small_Cap/Small_Cap/RCOM.csv')
df['RCOM']=temp["Close Price"]
temp=pd.read_csv('Small_Cap/Small_Cap/SONATSOFTW.csv')
df['SONATSOFTW']=temp["Close Price"]
temp=pd.read_csv('Small_Cap/Small_Cap/SUZLON.csv')
df['SUZLON']=temp["Close Price"]
temp=pd.read_csv('Small_Cap/Small_Cap/VENKEYS.csv')
df['VENKEYS']=temp["Close Price"]
temp=pd.read_csv('Small_Cap/Small_Cap/VIPIND.csv')
df['VIPIND']=temp["Close Price"]
temp=pd.read_csv('Small_Cap/Small_Cap/WELSPUNIND.csv')
df['WELSPUNIND']=temp["Close Price"]

# %% [markdown]
# ### TASK 6.2

# %%
datann=pd.DataFrame()
datann["annual_perc_ret"]=(df.pct_change().mean())*252
datann["volatality"]=(df.pct_change().std())*np.sqrt(252)

# %% [markdown]
# ### TASK 6.3

# %%
# K-Means Clustering
# Importing the dataset
X = datann.iloc[:,:].values

# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.show()

# %%
# Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 2, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
print(datann.idxmax())
# Out:
# annual_perc_ret    MUTHOOTFIN
# volatality         MUTHOOTFIN
# dtype: object

# %%
datann.drop('MUTHOOTFIN',inplace=True)

# %%
X = datann.iloc[:,:].values
Nc = range(1, 10)
kmeans = [KMeans(n_clusters=i) for i in Nc]
kmeans
score = [kmeans[i].fit(X).score(X) for i in range(len(kmeans))]
score
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.title('Elbow Curve')
plt.show()

# %%
X = datann.iloc[:,:].values
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
#plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.legend()
plt.show()
